# %% [markdown]
# ### Data Preprocessing
#
# ### Overview
#
# This notebook is used to make the over 2.5 predictions for all the matches saved in the `data/netx_matches.json` file.
#
# ### Pre-requisites
#
# 1. A conda environment is needed.
#
# For example:
# ```
# cd path/to/conda/dir
# conda env create -f aifootball_predictions.yaml
# conda activate aifootball_predictions
# python -m ipykernel install --user --name aifootball_predictions --display-name "aifootball_predictions"
# ```
#
# 2. All the trained models in the `models` directory
#
# 3. All the preprocessed dataset `data/preprocessed` which will be used to make the predictions
#
# ### Authors
#
# - mauo.andretta222@gmail.com

# %%
# install the necessary packages
import pandas as pd
import os
import json
import pickle
import numpy as np
from datetime import datetime

# %% [markdown]
# Specify useful features for the home and away teams, togheter with the netural features (related to no team)

# %%
home_team_features = [
    'HomeTeam',
    'FTHG', 'HG',  # Full Time Home Team Goals
    'HTHG',        # Half Time Home Team Goals
    'HS',          # Home Team Shots
    'HST',         # Home Team Shots on Target
    'HHW',         # Home Team Hit Woodwork
    'HC',          # Home Team Corners
    'HF',          # Home Team Fouls Committed
    'HFKC',        # Home Team Free Kicks Conceded
    'HO',          # Home Team Offsides
    'HY',          # Home Team Yellow Cards
    'HR',          # Home Team Red Cards
    'HBP',         # Home Team Bookings Points
    'B365H', 'BFH', 'BSH', 'BWH', 'GBH', 'IWH', 'LBH', 'PSH', 'SOH', 'SBH', 'SJH', 'SYH', 'VCH', 'WHH',  # Home win odds
    'BbMxH', 'BbAvH', 'MaxH', 'AvgH',  # Home win odds statistics
    'BFEH',       # Betfair Exchange home win odds
    'BbMxAHH', 'BbAvAHH', 'GBAHH', 'LBAHH', 'B365AHH', 'PAHH', 'MaxAHH', 'AvgAHH',  # Asian handicap home team odds
    'BbAHh', 'AHh', 'GBAH', 'LBAH', 'B365AH',  # Size of handicap (home team)
    'AvgHomeGoalsScored', 'AvgHomeGoalsConceded',
    'HomeOver2.5Perc',
    'AvgLast5HomeGoalsScored', 'AvgLast5HomeGoalsConceded',
    'Last5HomeOver2.5Count', 'Last5HomeOver2.5Perc'
]

# %%
away_team_features = [
    'AwayTeam',
    'FTAG', 'AG',  # Full Time Away Team Goals
    'HTAG',        # Half Time Away Team Goals
    'AS',          # Away Team Shots
    'AST',         # Away Team Shots on Target
    'AHW',         # Away Team Hit Woodwork
    'AC',          # Away Team Corners
    'AF',          # Away Team Fouls Committed
    'AFKC',        # Away Team Free Kicks Conceded
    'AO',          # Away Team Offsides
    'AY',          # Away Team Yellow Cards
    'AR',          # Away Team Red Cards
    'ABP',         # Away Team Bookings Points
    'B365A', 'BFA', 'BSA', 'BWA', 'GBA', 'IWA', 'LBA', 'PSA', 'SOA', 'SBA', 'SJA', 'SYA', 'VCA', 'WHA',  # Away win odds
    'BbMxA', 'BbAvA', 'MaxA', 'AvgA',  # Away win odds statistics
    'BFEA',       # Betfair Exchange away win odds
    'BbMxAHA', 'BbAvAHA', 'GBAHA', 'LBAHA', 'B365AHA', 'PAHA', 'MaxAHA', 'AvgAHA',  # Asian handicap away team odds
    'AvgAwayGoalsScored', 'AvgAwayGoalsConceded',
    'AwayOver2.5Perc',
    'AvgLast5AwayGoalsScored', 'AvgLast5AwayGoalsConceded',
    'Last5AwayOver2.5Count', 'Last5AwayOver2.5Perc'
]

# %%
general_features = [
    'Div',       # League Division
    'Date',      # Match Date
    'Time',      # Match Time
    'FTR', 'Res',  # Full Time Result
    'HTR',        # Half Time Result
    'Attendance', # Crowd Attendance
    'Referee',    # Match Referee
    'Bb1X2',      # Number of BetBrain bookmakers used to calculate match odds averages and maximums
    'BbMxD', 'BbAvD', 'MaxD', 'AvgD',  # Draw odds statistics
    'B365D', 'BFD', 'BSD', 'BWD', 'GBD', 'IWD', 'LBD', 'PSD', 'SOD', 'SBD', 'SJD', 'SYD', 'VCD', 'WHD',  # Draw odds
    'BbOU',       # Number of BetBrain bookmakers used to calculate over/under 2.5 goals
    'BbMx>2.5', 'BbAv>2.5', 'BbMx<2.5', 'BbAv<2.5',  # Over/Under 2.5 goals odds statistics
    'GB>2.5', 'GB<2.5', 'B365>2.5', 'B365<2.5', 'P>2.5', 'P<2.5', 'Max>2.5', 'Max<2.5', 'Avg>2.5', 'AvgC>2.5', 'Avg<2.5', 'AvgC<2.5', 'MaxCAHA',
    'MaxC>2.5', 'B365C<2.5',  'MaxCA', 'B365CAHH',# Over/Under 2.5 goals odds
    'BbAH',       # Number of BetBrain bookmakers used to Asian handicap averages and maximums
    'Over2.5'     # Binary indicator if the match ended with more than 2.5 total goals
]

# %%
# Open the JSON file and load its data into a dictionary
with open("../data/next_matches.json", 'r', encoding='utf-16') as json_file:
    data_dict = json.load(json_file)

# %%
data_dict
# Out:
# {'E0': {'id': 2021,
#   'crest': 'https://crests.football-data.org/PL.png',
#   'next_matches': [{'date': '2024-08-31 11:30:00',
#     'home_team': 'Arsenal',
#     'away_team': 'Brighton',
#     'home_team_crest': 'https://crests.football-data.org/57.png',
#     'away_team_crest': 'https://crests.football-data.org/397.png'},
#    {'date': '2024-08-31 14:00:00',
#     'home_team': 'Brentford',
#     'away_team': 'Southampton',
#     'home_team_crest': 'https://crests.football-data.org/402.png',
#     'away_team_crest': 'https://crests.football-data.org/340.png'},
#    {'date': '2024-08-31 14:00:00',
#     'home_team': 'Everton',
#     'away_team': 'Bournemouth',
#     'home_team_crest': 'https://crests.football-data.org/62.png',
#     'away_team_crest': 'https://crests.football-data.org/1044.png'},
#    {'date': '2024-08-31 14:00:00',
#     'home_team': 'Ipswich',
#     'away_team': 'Fulham',
#     'home_team_crest': 'https://crests.football-data.org/349.png',
#     'away_team_crest': 'https://crests.football-data.org/63.png'},
#    {'date': '2024-08-31 14:00:00',
#     'home_team': 'Leicester',
#     'away_team': 'Aston Villa',
#     'home_team_crest': 'https://crests.football-data.org/338.png',
#     'away_team_crest': 'https://crests.football-data.org/58.png'},
#    {'date': '2024-08-31 14:00:00',
#     'home_team': "Nott'm Forest",
#     'away_team': 'Wolves',
#     'home_team_crest': 'https://crests.football-data.org/351.png',
#     'away_team_crest': 'https://crests.football-data.org/76.png'},
#    {'date': '2024-08-31 16:30:00',
#     'home_team': 'West Ham',
#     'away_team': 'Man City',
#     'home_team_crest': 'https://crests.football-data.org/563.png',
#     'away_team_crest': 'https://crests.football-data.org/65.png'},
#    {'date': '2024-09-01 12:30:00',
#     'home_team': 'Chelsea',
#     'away_team': 'Crystal Palace',
#     'home_team_crest': 'https://crests.football-data.org/61.png',
#     'away_team_crest': 'https://crests.football-data.org/354.png'},
#    {'date': '2024-09-01 12:30:00',
#     'home_team': 'Newcastle',
#     'away_team': 'Tottenham',
#     'home_team_crest': 'https://crests.football-data.org/67.png',
#     'away_team_crest': 'https://crests.football-data.org/73.png'},
#    {'date': '2024-09-01 15:00:00',
#     'home_team': 'Man United',
#     'away_team': 'Liverpool',
#     'home_team_crest': 'https://crests.football-data.org/66.png',
#     'away_team_crest': 'https://crests.football-data.org/64.png'}]},
#  'SP1': {'id': 2014,
#   'crest': 'https://crests.football-data.org/PD.png',
#   'next_matches': [{'date': '2024-08-31 15:00:00',
#     'home_team': 'Barcelona',
#     'away_team': 'Valladolid',
#     'home_team_crest': 'https://crests.football-data.org/81.png',
#     'away_team_crest': 'https://crests.football-data.org/250.png'},
#    {'date': '2024-08-31 17:00:00',
#     'home_team': 'Ath Bilbao',
#     'away_team': 'Ath Madrid',
#     'home_team_crest': 'https://crests.football-data.org/77.png',
#     'away_team_crest': 'https://crests.football-data.org/78.png'},
#    {'date': '2024-08-31 17:15:00',
#     'home_team': 'Espanol',
#     'away_team': 'Vallecano',
#     'home_team_crest': 'https://crests.football-data.org/80.png',
#     'away_team_crest': 'https://crests.football-data.org/87.png'},
#    {'date': '2024-08-31 19:30:00',
#     'home_team': 'Leganes',
#     'away_team': 'Mallorca',
#     'home_team_crest': 'https://crests.football-data.org/745.png',
#     'away_team_crest': 'https://crests.football-data.org/89.png'},
#    {'date': '2024-08-31 19:30:00',
#     'home_team': 'Valencia',
#     'away_team': 'Villarreal',
#     'home_team_crest': 'https://crests.football-data.org/95.png',
#     'away_team_crest': 'https://crests.football-data.org/94.png'},
#    {'date': '2024-09-01 15:00:00',
#     'home_team': 'Osasuna',
#     'away_team': 'Celta',
#     'home_team_crest': 'https://crests.football-data.org/79.png',
#     'away_team_crest': 'https://crests.football-data.org/558.png'},
#    {'date': '2024-09-01 15:00:00',
#     'home_team': 'Alaves',
#     'away_team': 'Las Palmas',
#     'home_team_crest': 'https://crests.football-data.org/263.png',
#     'away_team_crest': 'https://crests.football-data.org/275.png'},
#    {'date': '2024-09-01 17:00:00',
#     'home_team': 'Sevilla',
#     'away_team': 'Girona',
#     'home_team_crest': 'https://crests.football-data.org/559.png',
#     'away_team_crest': 'https://crests.football-data.org/298.png'},
#    {'date': '2024-09-01 17:15:00',
#     'home_team': 'Getafe',
#     'away_team': 'Sociedad',
#     'home_team_crest': 'https://crests.football-data.org/82.png',
#     'away_team_crest': 'https://crests.football-data.org/92.png'},
#    {'date': '2024-09-01 19:30:00',
#     'home_team': 'Real Madrid',
#     'away_team': 'Betis',
#     'home_team_crest': 'https://crests.football-data.org/86.png',
#     'away_team_crest': 'https://crests.football-data.org/90.png'}]},
#  'I1': {'id': 2019,
#   'crest': 'https://crests.football-data.org/SA.png',
#   'next_matches': [{'date': '2024-08-30 16:30:00',
#     'home_team': 'Venezia',
#     'away_team': 'Torino',
#     'home_team_crest': 'https://crests.football-data.org/454.png',
#     'away_team_crest': 'https://crests.football-data.org/586.png'},
#    {'date': '2024-08-30 18:45:00',
#     'home_team': 'Inter',
#     'away_team': 'Atalanta',
#     'home_team_crest': 'https://crests.football-data.org/108.png',
#     'away_team_crest': 'https://crests.football-data.org/102.png'},
#    {'date': '2024-08-31 16:30:00',
#     'home_team': 'Bologna',
#     'away_team': 'Empoli',
#     'home_team_crest': 'https://crests.football-data.org/103.png',
#     'away_team_crest': 'https://crests.football-data.org/445.png'},
#    {'date': '2024-08-31 16:30:00',
#     'home_team': 'Lecce',
#     'away_team': 'Cagliari',
#     'home_team_crest': 'https://crests.football-data.org/5890.png',
#     'away_team_crest': 'https://crests.football-data.org/104.png'},
#    {'date': '2024-08-31 18:45:00',
#     'home_team': 'Lazio',
#     'away_team': 'Milan',
#     'home_team_crest': 'https://crests.football-data.org/110.png',
#     'away_team_crest': 'https://crests.football-data.org/98.png'},
#    {'date': '2024-08-31 18:45:00',
#     'home_team': 'Napoli',
#     'away_team': 'Parma',
#     'home_team_crest': 'https://crests.football-data.org/113.png',
#     'away_team_crest': 'https://crests.football-data.org/112.png'},
#    {'date': '2024-09-01 16:30:00',
#     'home_team': 'Fiorentina',
#     'away_team': 'Monza',
#     'home_team_crest': 'https://crests.football-data.org/99.png',
#     'away_team_crest': 'https://crests.football-data.org/5911.png'},
#    {'date': '2024-09-01 16:30:00',
#     'home_team': 'Genoa',
#     'away_team': 'Verona',
#     'home_team_crest': 'https://crests.football-data.org/107.png',
#     'away_team_crest': 'https://crests.football-data.org/450.png'},
#    {'date': '2024-09-01 18:45:00',
#     'home_team': 'Juventus',
#     'away_team': 'Roma',
#     'home_team_crest': 'https://crests.football-data.org/109.png',
#     'away_team_crest': 'https://crests.football-data.org/100.png'},
#    {'date': '2024-09-01 18:45:00',
#     'home_team': 'Udinese',
#     'away_team': 'Como',
#     'home_team_crest': 'https://crests.football-data.org/115.png',
#     'away_team_crest': 'https://crests.football-data.org/7397.png'}]},
#  'D1': {'id': 2002,
#   'crest': 'https://crests.football-data.org/BL1.png',
#   'next_matches': [{'date': '2024-08-30 18:30:00',
#     'home_team': 'Union Berlin',
#     'away_team': None,
#     'home_team_crest': 'https://crests.football-data.org/28.png',
#     'away_team_crest': 'https://crests.football-data.org/20.png'},
#    {'date': '2024-08-31 13:30:00',
#     'home_team': 'Stuttgart',
#     'away_team': 'Mainz',
#     'home_team_crest': 'https://crests.football-data.org/10.png',
#     'away_team_crest': 'https://crests.football-data.org/15.png'},
#    {'date': '2024-08-31 13:30:00',
#     'home_team': 'Ein Frankfurt',
#     'away_team': 'Hoffenheim',
#     'home_team_crest': 'https://crests.football-data.org/19.png',
#     'away_team_crest': 'https://crests.football-data.org/2.png'},
#    {'date': '2024-08-31 13:30:00',
#     'home_team': 'Werder Bremen',
#     'away_team': 'Dortmund',
#     'home_team_crest': 'https://crests.football-data.org/12.png',
#     'away_team_crest': 'https://crests.football-data.org/4.png'},
#    {'date': '2024-08-31 13:30:00',
#     'home_team': 'Bochum',
#     'away_team': "M'gladbach",
#     'home_team_crest': 'https://crests.football-data.org/36.png',
#     'away_team_crest': 'https://crests.football-data.org/18.png'},
#    {'date': '2024-08-31 13:30:00',
#     'home_team': None,
#     'away_team': 'Wolfsburg',
#     'home_team_crest': 'https://crests.football-data.org/720.png',
#     'away_team_crest': 'https://crests.football-data.org/11.png'},
#    {'date': '2024-08-31 16:30:00',
#     'home_team': 'Leverkusen',
#     'away_team': 'RB Leipzig',
#     'home_team_crest': 'https://crests.football-data.org/3.png',
#     'away_team_crest': 'https://crests.football-data.org/721.png'},
#    {'date': '2024-09-01 13:30:00',
#     'home_team': 'Heidenheim',
#     'away_team': 'Augsburg',
#     'home_team_crest': 'https://crests.football-data.org/44.png',
#     'away_team_crest': 'https://crests.football-data.org/16.png'},
#    {'date': '2024-09-01 15:30:00',
#     'home_team': 'Bayern Munich',
#     'away_team': 'Freiburg',
#     'home_team_crest': 'https://crests.football-data.org/5.png',
#     'away_team_crest': 'https://crests.football-data.org/17.png'}]},
#  'F1': {'id': 2015,
#   'crest': 'https://crests.football-data.org/FL1.png',
#   'next_matches': [{'date': '2024-08-30 18:45:00',
#     'home_team': 'Lyon',
#     'away_team': 'Strasbourg',
#     'home_team_crest': 'https://crests.football-data.org/523.png',
#     'away_team_crest': 'https://crests.football-data.org/576.png'},
#    {'date': '2024-08-31 15:00:00',
#     'home_team': 'Brest',
#     'away_team': 'St Etienne',
#     'home_team_crest': 'https://crests.football-data.org/512.png',
#     'away_team_crest': 'https://crests.football-data.org/527.png'},
#    {'date': '2024-08-31 17:00:00',
#     'home_team': 'Montpellier',
#     'away_team': 'Nantes',
#     'home_team_crest': 'https://crests.football-data.org/518.png',
#     'away_team_crest': 'https://crests.football-data.org/543.png'},
#    {'date': '2024-08-31 19:00:00',
#     'home_team': 'Toulouse',
#     'away_team': 'Marseille',
#     'home_team_crest': 'https://crests.football-data.org/511.png',
#     'away_team_crest': 'https://crests.football-data.org/516.png'},
#    {'date': '2024-09-01 13:00:00',
#     'home_team': 'Monaco',
#     'away_team': 'Lens',
#     'home_team_crest': 'https://crests.football-data.org/548.png',
#     'away_team_crest': 'https://crests.football-data.org/546.png'},
#    {'date': '2024-09-01 15:00:00',
#     'home_team': 'Angers',
#     'away_team': 'Nice',
#     'home_team_crest': 'https://crests.football-data.org/532.png',
#     'away_team_crest': 'https://crests.football-data.org/522.png'},
#    {'date': '2024-09-01 15:00:00',
#     'home_team': 'Le Havre',
#     'away_team': 'Auxerre',
#     'home_team_crest': 'https://crests.football-data.org/533.png',
#     'away_team_crest': 'https://crests.football-data.org/519.png'},
#    {'date': '2024-09-01 15:00:00',
#     'home_team': 'Reims',
#     'away_team': 'Rennes',
#     'home_team_crest': 'https://crests.football-data.org/547.png',
#     'away_team_crest': 'https://crests.football-data.org/529.png'},
#    {'date': '2024-09-01 18:45:00',
#     'home_team': 'Lille',
#     'away_team': 'Paris SG',
#     'home_team_crest': 'https://crests.football-data.org/521.png',
#     'away_team_crest': 'https://crests.football-data.org/524.png'}]}}

# %%
# Open the JSON file and load its data into a dictionary
json_competitions = '../data/next_matches.json'
with open(json_competitions, 'r', encoding='utf-16') as json_file:
    competitions = json.load(json_file)

# Define the models directory
models_dir = '../models'
# Define the data directory to make predictions
data_dir = '../data/processed'

VALID_LEAGUES = ["E0","I1", "D1", "SP1", "F1"]

# Initialize a variable to hold the Telegram message
telegram_message = f"🎯 **AI Football Predictions: Will There Be Over 2.5 Goals?** 🎯\n\nCheck out the latest predictions for the upcoming football matches! We've analyzed the data and here are our thoughts:\n PREDICTIONS DONE: {datetime.now().strftime('%Y-%m-%d')} \n\n"

for league in VALID_LEAGUES:
    # Iterate through the directory to find all .pkl files
    for filename in os.listdir(models_dir):
        # Check if the name of the file contains the league identifier
        if league in filename:
            # Checl if the file is a .pkl file
            if filename.endswith('.pkl'):
                filepath = os.path.join(models_dir, filename)

                # Load the model using pickle for the current league
                with open(filepath, 'rb') as file:
                    league_model = pickle.load(file)
    
    # Iterate through the directory to find all .csv files
    for filename in os.listdir(data_dir):
        # Check if the name of the file contains the league identifier
        if league in filename:
            # Check if the file is a .csv file
            if filename.endswith('.csv'):
                filepath = os.path.join(data_dir, filename)
                # Load the data using pandas for the current league
                league_data = pd.read_csv(filepath)

    # If the input_league_data and league_model is not empty, make the predictions
    if league_data is None and league_model is None:
        print(f"Could not find the data or model for the league {league}")
        continue
    # else make the predictions
    else:    
        # Make the predictions
        for competition_league, competitions_info in competitions.items():
            if competition_league == league:
                # Define the nationality flag to use in the message
                print(f"\n Making predictions for {league} \n")
                # Prepare the section for the current league
                league_section = f"🔵 **{competitions_info['name']}**:\n"
                for match in competitions_info["next_matches"]:            
                    home_team = match['home_team']
                    away_team = match['away_team']
                    print(f"Home team: {home_team}, Away team: {away_team}")

                    # row to predict
                    numeric_columns = league_data.select_dtypes(include=['number']).columns  # Get the column names for all the numeric columns

                    # If the column Over2.5 is in the numeric columns, remove it because it is the target column
                    if 'Over2.5' in numeric_columns:
                        numeric_columns = numeric_columns.drop('Over2.5')

                    # Define the row to predict 
                    row_to_predict = pd.DataFrame(columns=numeric_columns)  # Create an empty DataFrame with the numeric columns
                    row_to_predict.loc[len(row_to_predict)] = [None] * len(row_to_predict.columns)  # Initialize a new row with NaN

                    # Check if the home team is in the DataFrame
                    if home_team not in league_data['HomeTeam'].values:
                        print(f"Home team {home_team} not found in the {league} data, skipping to the next match")
                        continue

                    # Check if the away team is in the DataFrame
                    if away_team not in league_data['AwayTeam'].values:
                        print(f"Away team {away_team} not found in the {league} data, skipping to the next match")
                        continue

                    # get the data for the home team
                    home_team_df = league_data[league_data['HomeTeam'] == home_team]
                    # Sort the filtered DataFrame by Date in descending order
                    home_sorted_df = home_team_df.sort_values(by='Date', ascending=False)
                    # Select the first 5 rows
                    home_team_final_df = home_sorted_df.head(5)[numeric_columns]

                    # get the data for the home team
                    away_team_df = league_data[league_data['AwayTeam'] == away_team]
                    # Sort the filtered DataFrame by Date in descending order
                    away_sorted_df = away_team_df.sort_values(by='Date', ascending=False)
                    # Select the first 5 rows
                    away_team_final_df = away_sorted_df.head(5)[numeric_columns]

                    for column in row_to_predict.columns:
                        if column in home_team_features:
                            #print(f"Column in the home_team_df: {column}")
                            row_to_predict.loc[len(row_to_predict)-1,column] = home_team_final_df[column].mean()
                        elif column in away_team_features:
                            #print(f"Column in the away_team_df: {column}")
                            row_to_predict.loc[len(row_to_predict)-1, column] = away_team_final_df[column].mean()
                        elif column in general_features:
                            #print(f"Column in the general_features: {column}")
                            row_to_predict.loc[len(row_to_predict)-1,column] = away_team_final_df[column].mean() + home_team_final_df[column].mean() / 2
                        else:
                            print(f"Column {column} not found in the home_team_df, away_team_df and general_features")


                    # Make the prediction
                    X_test = row_to_predict.values
                    prediction = league_model.predict(X_test)
                    predicted_probability = league_model.predict_proba(X_test)[0]

                    if prediction == 1:
                        print(f"The match between {home_team} and {away_team} will end with more than 2.5 goals. With a probability of {[round (prediction,2) for prediction in predicted_probability]}")
                        result = f"Over 2.5 Goals! 🔥 ({round(predicted_probability[1] * 100, 2)}% chance)"
                    else:
                        print(f"The match between {home_team} and {away_team} will end with less than 2.5 goals. With a probability of {[round (prediction,2) for prediction in predicted_probability]}")
                        result = f"Under 2.5 Goals ({round(predicted_probability[0] * 100, 2)}% chance)"

                    # Add the match result to the league section
                    league_section += f"- **{home_team}** 🆚 **{away_team}**: {result}\n"

        # Add the league section to the Telegram message
        telegram_message += league_section + "\n"
# Out:
#  Making predictions for E0
#
# Home team: Arsenal, Away team: Brighton
# The match between Arsenal and Brighton will end with more than 2.5 goals. With a probability of [0.36, 0.64]
# Home team: Brentford, Away team: Southampton
# The match between Brentford and Southampton will end with less than 2.5 goals. With a probability of [0.79, 0.21]
# Home team: Everton, Away team: Bournemouth
# The match between Everton and Bournemouth will end with less than 2.5 goals. With a probability of [0.74, 0.26]
# Home team: Ipswich, Away team: Fulham
# The match between Ipswich and Fulham will end with less than 2.5 goals. With a probability of [0.9, 0.1]
# Home team: Leicester, Away team: Aston Villa
# The match between Leicester and Aston Villa will end with less than 2.5 goals. With a probability of [0.56, 0.44]
# Home team: Nott'm Forest, Away team: Wolves
# The match between Nott'm Forest and Wolves will end with less than 2.5 goals. With a probability of [0.79, 0.21]
# Home team: West Ham, Away team: Man City
# The match between West Ham and Man City will end with less than 2.5 goals. With a probability of [0.6, 0.4]
# Home team: Chelsea, Away team: Crystal Palace
# The match between Chelsea and Crystal Palace will end with more than 2.5 goals. With a probability of [0.4, 0.6]
# Home team: Newcastle, Away team: Tottenham
# The match between Newcastle and Tottenham will end with less than 2.5 goals. With a probability of [0.54, 0.46]
# Home team: Man United, Away team: Liverpool
# The match between Man United and Liverpool will end with more than 2.5 goals. With a probability of [0.45, 0.55]
#
#  Making predictions for I1
#
# Home team: Venezia, Away team: Torino
# Home team Venezia not found in the I1 data, skipping to the next match
# Home team: Inter, Away team: Atalanta
# The match between Inter and Atalanta will end with more than 2.5 goals. With a probability of [0.11, 0.89]
# Home team: Bologna, Away team: Empoli
# The match between Bologna and Empoli will end with less than 2.5 goals. With a probability of [0.9, 0.1]
# Home team: Lecce, Away team: Cagliari
# The match between Lecce and Cagliari will end with less than 2.5 goals. With a probability of [0.69, 0.31]
# Home team: Lazio, Away team: Milan
# The match between Lazio and Milan will end with more than 2.5 goals. With a probability of [0.18, 0.82]
# Home team: Napoli, Away team: Parma
# Away team Parma not found in the I1 data, skipping to the next match
# Home team: Fiorentina, Away team: Monza
# The match between Fiorentina and Monza will end with less than 2.5 goals. With a probability of [0.62, 0.38]
# Home team: Genoa, Away team: Verona
# The match between Genoa and Verona will end with less than 2.5 goals. With a probability of [0.53, 0.47]
# Home team: Juventus, Away team: Roma
# The match between Juventus and Roma will end with more than 2.5 goals. With a probability of [0.46, 0.54]
# Home team: Udinese, Away team: Como
# The match between Udinese and Como will end with more than 2.5 goals. With a probability of [0.43, 0.57]
#
#  Making predictions for D1
#
# Home team: Union Berlin, Away team: None
# Away team None not found in the D1 data, skipping to the next match
# Home team: Stuttgart, Away team: Mainz
# The match between Stuttgart and Mainz will end with more than 2.5 goals. With a probability of [0.42, 0.58]
# Home team: Ein Frankfurt, Away team: Hoffenheim
# The match between Ein Frankfurt and Hoffenheim will end with more than 2.5 goals. With a probability of [0.17, 0.83]
# Home team: Werder Bremen, Away team: Dortmund
# The match between Werder Bremen and Dortmund will end with more than 2.5 goals. With a probability of [0.49, 0.51]
# Home team: Bochum, Away team: M'gladbach
# The match between Bochum and M'gladbach will end with more than 2.5 goals. With a probability of [0.33, 0.67]
# Home team: None, Away team: Wolfsburg
# Home team None not found in the D1 data, skipping to the next match
# Home team: Leverkusen, Away team: RB Leipzig
# The match between Leverkusen and RB Leipzig will end with more than 2.5 goals. With a probability of [0.09, 0.91]
# Home team: Heidenheim, Away team: Augsburg
# The match between Heidenheim and Augsburg will end with more than 2.5 goals. With a probability of [0.25, 0.75]
# Home team: Bayern Munich, Away team: Freiburg
# The match between Bayern Munich and Freiburg will end with more than 2.5 goals. With a probability of [0.23, 0.77]
#
#  Making predictions for SP1
#
# Home team: Barcelona, Away team: Valladolid
# The match between Barcelona and Valladolid will end with more than 2.5 goals. With a probability of [0.23, 0.77]
# Home team: Ath Bilbao, Away team: Ath Madrid
# The match between Ath Bilbao and Ath Madrid will end with less than 2.5 goals. With a probability of [0.56, 0.44]
# Home team: Espanol, Away team: Vallecano
# The match between Espanol and Vallecano will end with more than 2.5 goals. With a probability of [0.16, 0.84]
# Home team: Leganes, Away team: Mallorca
# Home team Leganes not found in the SP1 data, skipping to the next match
# Home team: Valencia, Away team: Villarreal
# The match between Valencia and Villarreal will end with less than 2.5 goals. With a probability of [0.5, 0.5]
# Home team: Osasuna, Away team: Celta
# The match between Osasuna and Celta will end with more than 2.5 goals. With a probability of [0.28, 0.72]
# Home team: Alaves, Away team: Las Palmas
# The match between Alaves and Las Palmas will end with less than 2.5 goals. With a probability of [0.88, 0.12]
# Home team: Sevilla, Away team: Girona
# The match between Sevilla and Girona will end with more than 2.5 goals. With a probability of [0.3, 0.7]
# Home team: Getafe, Away team: Sociedad
# The match between Getafe and Sociedad will end with less than 2.5 goals. With a probability of [0.59, 0.41]
# Home team: Real Madrid, Away team: Betis
# The match between Real Madrid and Betis will end with more than 2.5 goals. With a probability of [0.2, 0.8]
#
#  Making predictions for F1
#
# Home team: Lyon, Away team: Strasbourg
# The match between Lyon and Strasbourg will end with more than 2.5 goals. With a probability of [0.42, 0.58]
# Home team: Brest, Away team: St Etienne
# The match between Brest and St Etienne will end with less than 2.5 goals. With a probability of [0.95, 0.05]
# Home team: Montpellier, Away team: Nantes
# The match between Montpellier and Nantes will end with less than 2.5 goals. With a probability of [0.84, 0.16]
# Home team: Toulouse, Away team: Marseille
# The match between Toulouse and Marseille will end with more than 2.5 goals. With a probability of [0.27, 0.73]
# Home team: Monaco, Away team: Lens
# The match between Monaco and Lens will end with less than 2.5 goals. With a probability of [0.62, 0.38]
# Home team: Angers, Away team: Nice
# The match between Angers and Nice will end with less than 2.5 goals. With a probability of [0.59, 0.41]
# Home team: Le Havre, Away team: Auxerre
# The match between Le Havre and Auxerre will end with less than 2.5 goals. With a probability of [0.82, 0.18]
# Home team: Reims, Away team: Rennes
# The match between Reims and Rennes will end with less than 2.5 goals. With a probability of [0.8, 0.2]
# Home team: Lille, Away team: Paris SG
# The match between Lille and Paris SG will end with more than 2.5 goals. With a probability of [0.19, 0.81]

# %%
print(telegram_message)
# Out:
# 🎯 **AI Football Predictions: Will There Be Over 2.5 Goals?** 🎯
#
# Check out the latest predictions for the upcoming football matches! We've analyzed the data and here are our thoughts:
#  PREDICTIONS DONE: 2024-08-26
#
# 🔵 **Premier League**:
# - **Arsenal** 🆚 **Brighton**: Over 2.5 Goals! 🔥 (63.69% chance)
# - **Brentford** 🆚 **Southampton**: Under 2.5 Goals (79.34% chance)
# - **Everton** 🆚 **Bournemouth**: Under 2.5 Goals (74.1% chance)
# - **Ipswich** 🆚 **Fulham**: Under 2.5 Goals (90.29% chance)
# - **Leicester** 🆚 **Aston Villa**: Under 2.5 Goals (56.04% chance)
# - **Nott'm Forest** 🆚 **Wolves**: Under 2.5 Goals (79.5% chance)
# - **West Ham** 🆚 **Man City**: Under 2.5 Goals (60.28% chance)
# - **Chelsea** 🆚 **Crystal Palace**: Over 2.5 Goals! 🔥 (60.26% chance)
# - **Newcastle** 🆚 **Tottenham**: Under 2.5 Goals (53.83% chance)
# - **Man United** 🆚 **Liverpool**: Over 2.5 Goals! 🔥 (55.03% chance)
#
# 🔵 **Serie A**:
# - **Inter** 🆚 **Atalanta**: Over 2.5 Goals! 🔥 (89.08% chance)
# - **Bologna** 🆚 **Empoli**: Under 2.5 Goals (90.46% chance)
# - **Lecce** 🆚 **Cagliari**: Under 2.5 Goals (69.31% chance)
# - **Lazio** 🆚 **Milan**: Over 2.5 Goals! 🔥 (82.24% chance)
# - **Fiorentina** 🆚 **Monza**: Under 2.5 Goals (62.08% chance)
# - **Genoa** 🆚 **Verona**: Under 2.5 Goals (53.41% chance)
# - **Juventus** 🆚 **Roma**: Over 2.5 Goals! 🔥 (53.78% chance)
# - **Udinese** 🆚 **Como**: Over 2.5 Goals! 🔥 (57.17% chance)
#
# 🔵 **Bundesliga**:
# - **Stuttgart** 🆚 **Mainz**: Over 2.5 Goals! 🔥 (57.71% chance)
# - **Ein Frankfurt** 🆚 **Hoffenheim**: Over 2.5 Goals! 🔥 (82.58% chance)
# - **Werder Bremen** 🆚 **Dortmund**: Over 2.5 Goals! 🔥 (51.23% chance)
# - **Bochum** 🆚 **M'gladbach**: Over 2.5 Goals! 🔥 (67.31% chance)
# - **Leverkusen** 🆚 **RB Leipzig**: Over 2.5 Goals! 🔥 (91.22% chance)
# - **Heidenheim** 🆚 **Augsburg**: Over 2.5 Goals! 🔥 (75.02% chance)
# - **Bayern Munich** 🆚 **Freiburg**: Over 2.5 Goals! 🔥 (77.39% chance)
#
# 🔵 **La Liga**:
# - **Barcelona** 🆚 **Valladolid**: Over 2.5 Goals! 🔥 (77.37% chance)
# - **Ath Bilbao** 🆚 **Ath Madrid**: Under 2.5 Goals (55.98% chance)
# - **Espanol** 🆚 **Vallecano**: Over 2.5 Goals! 🔥 (83.82% chance)
# - **Valencia** 🆚 **Villarreal**: Under 2.5 Goals (50.35% chance)
# - **Osasuna** 🆚 **Celta**: Over 2.5 Goals! 🔥 (71.52% chance)
# - **Alaves** 🆚 **Las Palmas**: Under 2.5 Goals (88.44% chance)
# - **Sevilla** 🆚 **Girona**: Over 2.5 Goals! 🔥 (69.66% chance)
# - **Getafe** 🆚 **Sociedad**: Under 2.5 Goals (58.96% chance)
# - **Real Madrid** 🆚 **Betis**: Over 2.5 Goals! 🔥 (79.6% chance)
#
# 🔵 **Ligue 1**:
# - **Lyon** 🆚 **Strasbourg**: Over 2.5 Goals! 🔥 (58.12% chance)
# - **Brest** 🆚 **St Etienne**: Under 2.5 Goals (94.52% chance)
# - **Montpellier** 🆚 **Nantes**: Under 2.5 Goals (83.7% chance)
# - **Toulouse** 🆚 **Marseille**: Over 2.5 Goals! 🔥 (73.32% chance)
# - **Monaco** 🆚 **Lens**: Under 2.5 Goals (61.56% chance)
# - **Angers** 🆚 **Nice**: Under 2.5 Goals (59.45% chance)
# - **Le Havre** 🆚 **Auxerre**: Under 2.5 Goals (81.59% chance)
# - **Reims** 🆚 **Rennes**: Under 2.5 Goals (79.82% chance)
# - **Lille** 🆚 **Paris SG**: Over 2.5 Goals! 🔥 (80.78% chance)

# %%
# File path and name
file_path = "telegram_post.txt"

# Saving the string to a file
with open(file_path, 'w', encoding='utf-8') as file:
    file.write(telegram_message)

# %%
home_team_final_df.head()
# Out:
#      Last5HomeOver2.5Perc  Last5AwayOver2.5Perc  HST  AST  HomeOver2.5Perc  \
# 365                   0.0                   0.0    5    2             0.00
# 575                  60.0                  60.0    8    8            68.42
# 37                   40.0                  40.0    2    5            68.42
# 210                  60.0                  60.0   10    7            68.42
# 631                  80.0                  60.0   13    4            68.42
#
#      AvgLast5AwayGoalsConceded  AwayOver2.5Perc  AvgLast5HomeGoalsScored  \
# 365                        1.0             0.00                      1.0
# 575                        1.8            73.68                      2.0
# 37                         0.4            52.63                      1.8
# 210                        1.4            63.16                      2.0
# 631                        2.4            57.89                      2.4
#
#      AvgLast5HomeGoalsConceded  AvgLast5AwayGoalsScored  MaxC>2.5  B365C<2.5  \
# 365                        0.0                      0.0      1.66       2.30
# 575                        1.6                      1.8      1.40       3.20
# 37                         1.2                      1.8      1.40       3.00
# 210                        1.4                      1.8      1.41       3.75
# 631                        1.2                      1.0      1.37       3.40
#
#      AvgHomeGoalsScored  HR
# 365                1.00   0
# 575                1.63   0
# 37                 1.63   0
# 210                1.63   0
# 631                1.63   0

# %%
away_team_final_df.head()
# Out:
#      Last5HomeOver2.5Perc  Last5AwayOver2.5Perc  HST  AST  HomeOver2.5Perc  \
# 442                   0.0                   0.0    2    5             0.00
# 441                  80.0                  80.0    5    7            78.95
# 440                  40.0                  60.0    8    8            52.63
# 439                  20.0                  60.0    6    7            36.84
# 438                  80.0                  80.0    5    7            63.16
#
#      AvgLast5AwayGoalsConceded  AwayOver2.5Perc  AvgLast5HomeGoalsScored  \
# 442                        0.0             0.00                      0.0
# 441                        2.0            63.16                      2.6
# 440                        1.4            63.16                      1.2
# 439                        1.2            63.16                      1.4
# 438                        1.4            63.16                      1.6
#
#      AvgLast5HomeGoalsConceded  AvgLast5AwayGoalsScored  MaxC>2.5  B365C<2.5  \
# 442                        2.0                      2.0      1.40       3.20
# 441                        1.8                      2.0      1.39       3.20
# 440                        1.6                      1.6      1.42       3.20
# 439                        0.8                      2.0      1.53       2.63
# 438                        1.2                      2.2      1.48       2.75
#
#      AvgHomeGoalsScored  HR
# 442                0.00   0
# 441                2.53   0
# 440                1.63   0
# 439                1.16   0
# 438                1.63   0

# %%
row_to_predict.head()
# Out:
#   Last5HomeOver2.5Perc Last5AwayOver2.5Perc  HST  AST HomeOver2.5Perc  \
# 0                 48.0                 56.0  7.6  6.8          54.736
#
#   AvgLast5AwayGoalsConceded AwayOver2.5Perc AvgLast5HomeGoalsScored  \
# 0                       1.2          50.528                    1.84
#
#   AvgLast5HomeGoalsConceded AvgLast5AwayGoalsScored MaxC>2.5 B365C<2.5  \
# 0                      1.08                    1.96    2.168     4.561
#
#   AvgHomeGoalsScored   HR
# 0              1.504  0.0

# %%
X_test = row_to_predict.values
X_test
# Out:
# array([[48.0, 56.0, 7.6, 6.8, 54.736000000000004, 1.2, 50.528,
#         1.8399999999999999, 1.0799999999999998, 1.9600000000000002,
#         2.168, 4.561, 1.504, 0.0]], dtype=object)

# %%
prediction = models['uk_model'].predict(X_test)
print(f"Prediction: {prediction}")
# Out:
# Prediction: [1]

# %%
# get the probabilities
prediction = models['uk_model'].predict_proba(X_test)[0]
print(f"Prediction probabilities of Over2.5: {[round (prediction,2) for prediction in prediction]}")
# Out:
# Prediction probabilities of Over2.5: [0.45, 0.55]
